# %%
import requests
from bs4 import BeautifulSoup
import datetime
import re

# %%
url = "https://ria.ru/20231231/putin-1919273330.html"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
article = soup.find_all("div", attrs={"class" : "article__body js-mediator-article mia-analytics"})
article[0].text
# Out:
# 'Владимир Путин выступает с новогодним обращением к россиянам.'

# %%
date = datetime.date(year=2023,month=12,day=31).strftime("%Y%m%d")
url = f"https://ria.ru/services/{date}/more.html?id=0&date=20231231T235959"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup.find_all(name="div", attrs={"class" : "list-item"})
# Out:
# [<div class="list-item"><div class="list-item__content"><a class="list-item__image" href="https://ria.ru/20231231/putin-1919273330.html"><picture><source media="(min-width: 1160px)" media-type="ar16x9" srcset="https://cdnn21.img.ria.ru/images/07e7/0c/1f/1919270915_0:0:1920:1080_203x0_80_0_0_2aa5762e865bd4c13ba217cb5b2d836a.jpg"/><source media="(min-width: 480px)" media-type="ar16x9" srcset="https://cdnn21.img.ria.ru/images/07e7/0c/1f/1919270915_0:0:1920:1080_260x0_80_0_0_ab48e4800180b442ed3bf60630924597.jpg"/><source media="(min-width: 0px)" media-type="ar4x3" srcset="https://cdnn21.img.ria.ru/images/07e7/0c/1f/1919270915_240:0:1680:1080_180x0_80_0_0_07159e606ba709284851fbf4c6dfe73d.jpg"/><img alt="LIVE: Новогоднее обращение Путина к россиянам " class="responsive_img m-list-img" data-crop-height="338" data-crop-ratio="0.5625" data-crop-width="600" data-responsive0="https://cdnn21.img.ria.ru/images/07e7/0c/1f/1919270915_240:0:1680:1080_180x0_80_0_0_07159e606ba709284851fbf4c6dfe73d.jpg
# ...

# %%
import locale
locale.setlocale(locale.LC_ALL, "ru_RU.UTF-8")

date_str = soup.find_all(name="div", attrs={"class" : "list-item"})[0].find('div', {"class" : "list-item__date"}).text
datetime.datetime.strptime(date_str, "%d %B %Y, %H:%M")
# Out:
# datetime.datetime(2023, 12, 31, 23, 57)

# %%
re.findall(pattern=r'\d+', string=href.split("/")[4])[0]
# Out:
# '1919273330'

# %%
date = datetime.datetime(year=2023,month=12,day=31, hour=0,minute=5,second=0)
date - datetime.timedelta(minutes=date.minute+1)
# Out:
# datetime.datetime(2023, 12, 30, 23, 59)
